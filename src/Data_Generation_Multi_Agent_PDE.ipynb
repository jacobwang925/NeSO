# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install py-pde
# Out:
# Collecting py-pde
#   Downloading py_pde-0.44.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: matplotlib>=3.1 in /usr/local/lib/python3.11/dist-packages (from py-pde) (3.10.0)
# Requirement already satisfied: numba>=0.59 in /usr/local/lib/python3.11/dist-packages (from py-pde) (0.60.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from py-pde) (1.26.4)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.11/dist-packages (from py-pde) (1.14.1)
# Requirement already satisfied: sympy>=1.9 in /usr/local/lib/python3.11/dist-packages (from py-pde) (1.13.1)
# Requirement already satisfied: tqdm>=4.66 in /usr/local/lib/python3.11/dist-packages (from py-pde) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.59->py-pde) (0.43.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.9->py-pde) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1->py-pde) (1.17.0)
# Downloading py_pde-0.44.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.0/331.0 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: py-pde
# Successfully installed py-pde-0.44.0

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from pde import CartesianGrid, ScalarField, PDEBase, MemoryStorage
from scipy.io import savemat

# Fixed parameters
beta_1 = 1
sigma = 0.2
N = 7
# Fixed eigenvalues for each mode
lambda_val = [0, 0.7091, 2.0567, 3.1134, 4.6842, 5.3759, 6.0607]

# Directory for saving data files and figures
save_dir = '/content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/'
os.makedirs(save_dir, exist_ok=True)

# Number of configurations to generate
num_configs = 10
# Generate 10 beta_2 values evenly spaced between 0 and 2
beta2_values = np.linspace(0.5, 2, num_configs)

config_num = 1
for beta_2 in beta2_values:
    print(f"\n--- Config {config_num}: beta_2 = {beta_2:.3f} ---")

    # Randomly generate threshold values for each mode in this config
    thresholds = np.random.uniform(1, 2, N)

    # Loop over the modes (each mode uses its corresponding eigenvalue and a random threshold)
    for mode_num in range(N):
        theta = beta_1 + lambda_val[mode_num]
        current_threshold = thresholds[mode_num]
        print(f"Config {config_num}, Mode {mode_num}: theta = {theta:.3f}, threshold = {current_threshold:.3f}")

        # Define the PDE for the current mode. Note that beta_2 is taken from the current config.
        class FeynmanKacPDE(PDEBase):
            def __init__(self, theta, sigma, bc='dirichlet'):
                self.theta = theta
                self.sigma = sigma
                self.bc = bc

            def evolution_rate(self, state, t=0):
                state_gradient = state.gradient(bc=self.bc)
                state_laplacian = state.laplace(bc=self.bc)
                x, y = state.grid.cell_coords[..., 0], state.grid.cell_coords[..., 1]

                # Advection in x and y and isotropic diffusion
                advection_x = y * state_gradient[0]
                advection_y = - (self.theta * x + beta_2 * y) * state_gradient[1]
                diffusion = (self.sigma**2 / 2) * state_laplacian
                return advection_x + advection_y + diffusion

        # Create the grid with the domain defined by the current threshold
        grid = CartesianGrid([[-current_threshold, current_threshold],
                              [-current_threshold, current_threshold]], [256, 256])
        # Use a constant initial condition over the grid
        ic = ScalarField(grid, 1)

        # Instantiate the PDE
        pde = FeynmanKacPDE(theta, sigma)
        sampling_interval = 0.1
        storage = MemoryStorage()

        # Solve the PDE for t in [0, 10] with a small timestep
        pde.solve(ic, t_range=10, dt=1e-4, tracker=storage.tracker(sampling_interval))

        # Save the simulation data into a MATLAB file.
        data_filename = os.path.join(
            save_dir,
            f"SafeProb_FK_GeneralGraph_solData_config{config_num}_mode{mode_num}_beta2={beta_2:.2f}_thres={current_threshold:.2f}.mat"
        )
        data_variable_name = f"data_config{config_num}_mode{mode_num}"
        savemat(data_filename, {data_variable_name: np.array(storage.data), 'times': storage.times})
        print(f"Saved data: {data_filename}")

        # (Optional) Plot the solution at selected times and save the plot in PDF format.
        times_to_plot = np.linspace(0, 10, 11)
        fields = []
        for t in times_to_plot:
            closest_index = np.argmin(np.abs(storage.times - t))
            field_data = storage.data[closest_index]
            field = ScalarField(grid, field_data)
            fields.append(field)

        fig, axes = plt.subplots(3, 4, figsize=(16, 12))
        for ax, field, t in zip(axes.flat[:11], fields, times_to_plot):
            field.plot(ax=ax, title=f't = {t:.1f}', vmin=0, vmax=1, cmap='PuBu')
        # Remove any extra subplot
        fig.delaxes(axes.flat[-1])
        plt.tight_layout()

        plot_filename = os.path.join(
            save_dir,
            f"SafeProb_FK_GeneralGraph_Plot_config{config_num}_mode{mode_num}_beta2={beta_2:.2f}_thres={current_threshold:.2f}.pdf"
        )
        plt.savefig(plot_filename)
        plt.close(fig)
        print(f"Saved plot: {plot_filename}")

    config_num += 1
# Out:
# --- Config 1: beta_2 = 0.500 ---
# Config 1, Mode 0: theta = 1.000, threshold = 1.998
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config1_mode0_beta2=0.50_thres=2.00.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config1_mode0_beta2=0.50_thres=2.00.pdf
# Config 1, Mode 1: theta = 1.709, threshold = 1.907
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config1_mode1_beta2=0.50_thres=1.91.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config1_mode1_beta2=0.50_thres=1.91.pdf
# Config 1, Mode 2: theta = 3.057, threshold = 1.148
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config1_mode2_beta2=0.50_thres=1.15.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config1_mode2_beta2=0.50_thres=1.15.pdf
# Config 1, Mode 3: theta = 4.113, threshold = 1.384
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config1_mode3_beta2=0.50_thres=1.38.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config1_mode3_beta2=0.50_thres=1.38.pdf
# Config 1, Mode 4: theta = 5.684, threshold = 1.358
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config1_mode4_beta2=0.50_thres=1.36.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config1_mode4_beta2=0.50_thres=1.36.pdf
# Config 1, Mode 5: theta = 6.376, threshold = 1.444
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config1_mode5_beta2=0.50_thres=1.44.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config1_mode5_beta2=0.50_thres=1.44.pdf
# Config 1, Mode 6: theta = 7.061, threshold = 1.986
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config1_mode6_beta2=0.50_thres=1.99.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config1_mode6_beta2=0.50_thres=1.99.pdf
#
# --- Config 2: beta_2 = 0.667 ---
# Config 2, Mode 0: theta = 1.000, threshold = 1.002
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config2_mode0_beta2=0.67_thres=1.00.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config2_mode0_beta2=0.67_thres=1.00.pdf
# Config 2, Mode 1: theta = 1.709, threshold = 1.162
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config2_mode1_beta2=0.67_thres=1.16.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config2_mode1_beta2=0.67_thres=1.16.pdf
# Config 2, Mode 2: theta = 3.057, threshold = 1.037
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config2_mode2_beta2=0.67_thres=1.04.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config2_mode2_beta2=0.67_thres=1.04.pdf
# Config 2, Mode 3: theta = 4.113, threshold = 1.125
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config2_mode3_beta2=0.67_thres=1.12.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config2_mode3_beta2=0.67_thres=1.12.pdf
# Config 2, Mode 4: theta = 5.684, threshold = 1.992
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config2_mode4_beta2=0.67_thres=1.99.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config2_mode4_beta2=0.67_thres=1.99.pdf
# Config 2, Mode 5: theta = 6.376, threshold = 1.939
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config2_mode5_beta2=0.67_thres=1.94.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config2_mode5_beta2=0.67_thres=1.94.pdf
# Config 2, Mode 6: theta = 7.061, threshold = 1.283
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config2_mode6_beta2=0.67_thres=1.28.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config2_mode6_beta2=0.67_thres=1.28.pdf
#
# --- Config 3: beta_2 = 0.833 ---
# Config 3, Mode 0: theta = 1.000, threshold = 1.217
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config3_mode0_beta2=0.83_thres=1.22.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config3_mode0_beta2=0.83_thres=1.22.pdf
# Config 3, Mode 1: theta = 1.709, threshold = 1.454
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config3_mode1_beta2=0.83_thres=1.45.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config3_mode1_beta2=0.83_thres=1.45.pdf
# Config 3, Mode 2: theta = 3.057, threshold = 1.227
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config3_mode2_beta2=0.83_thres=1.23.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config3_mode2_beta2=0.83_thres=1.23.pdf
# Config 3, Mode 3: theta = 4.113, threshold = 1.274
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config3_mode3_beta2=0.83_thres=1.27.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config3_mode3_beta2=0.83_thres=1.27.pdf
# Config 3, Mode 4: theta = 5.684, threshold = 1.330
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config3_mode4_beta2=0.83_thres=1.33.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config3_mode4_beta2=0.83_thres=1.33.pdf
# Config 3, Mode 5: theta = 6.376, threshold = 1.877
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config3_mode5_beta2=0.83_thres=1.88.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config3_mode5_beta2=0.83_thres=1.88.pdf
# Config 3, Mode 6: theta = 7.061, threshold = 1.886
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config3_mode6_beta2=0.83_thres=1.89.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config3_mode6_beta2=0.83_thres=1.89.pdf
#
# --- Config 4: beta_2 = 1.000 ---
# Config 4, Mode 0: theta = 1.000, threshold = 1.328
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config4_mode0_beta2=1.00_thres=1.33.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config4_mode0_beta2=1.00_thres=1.33.pdf
# Config 4, Mode 1: theta = 1.709, threshold = 1.830
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config4_mode1_beta2=1.00_thres=1.83.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config4_mode1_beta2=1.00_thres=1.83.pdf
# Config 4, Mode 2: theta = 3.057, threshold = 1.472
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config4_mode2_beta2=1.00_thres=1.47.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config4_mode2_beta2=1.00_thres=1.47.pdf
# Config 4, Mode 3: theta = 4.113, threshold = 1.963
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config4_mode3_beta2=1.00_thres=1.96.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config4_mode3_beta2=1.00_thres=1.96.pdf
# Config 4, Mode 4: theta = 5.684, threshold = 1.855
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config4_mode4_beta2=1.00_thres=1.86.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config4_mode4_beta2=1.00_thres=1.86.pdf
# Config 4, Mode 5: theta = 6.376, threshold = 1.572
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config4_mode5_beta2=1.00_thres=1.57.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config4_mode5_beta2=1.00_thres=1.57.pdf
# Config 4, Mode 6: theta = 7.061, threshold = 1.702
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config4_mode6_beta2=1.00_thres=1.70.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config4_mode6_beta2=1.00_thres=1.70.pdf
#
# --- Config 5: beta_2 = 1.167 ---
# Config 5, Mode 0: theta = 1.000, threshold = 1.625
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config5_mode0_beta2=1.17_thres=1.62.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config5_mode0_beta2=1.17_thres=1.62.pdf
# Config 5, Mode 1: theta = 1.709, threshold = 1.666
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config5_mode1_beta2=1.17_thres=1.67.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config5_mode1_beta2=1.17_thres=1.67.pdf
# Config 5, Mode 2: theta = 3.057, threshold = 1.507
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config5_mode2_beta2=1.17_thres=1.51.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config5_mode2_beta2=1.17_thres=1.51.pdf
# Config 5, Mode 3: theta = 4.113, threshold = 1.481
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config5_mode3_beta2=1.17_thres=1.48.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config5_mode3_beta2=1.17_thres=1.48.pdf
# Config 5, Mode 4: theta = 5.684, threshold = 1.071
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config5_mode4_beta2=1.17_thres=1.07.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config5_mode4_beta2=1.17_thres=1.07.pdf
# Config 5, Mode 5: theta = 6.376, threshold = 1.338
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config5_mode5_beta2=1.17_thres=1.34.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config5_mode5_beta2=1.17_thres=1.34.pdf
# Config 5, Mode 6: theta = 7.061, threshold = 1.144
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config5_mode6_beta2=1.17_thres=1.14.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config5_mode6_beta2=1.17_thres=1.14.pdf
#
# --- Config 6: beta_2 = 1.333 ---
# Config 6, Mode 0: theta = 1.000, threshold = 1.816
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config6_mode0_beta2=1.33_thres=1.82.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config6_mode0_beta2=1.33_thres=1.82.pdf
# Config 6, Mode 1: theta = 1.709, threshold = 1.774
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config6_mode1_beta2=1.33_thres=1.77.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config6_mode1_beta2=1.33_thres=1.77.pdf
# Config 6, Mode 2: theta = 3.057, threshold = 1.787
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config6_mode2_beta2=1.33_thres=1.79.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config6_mode2_beta2=1.33_thres=1.79.pdf
# Config 6, Mode 3: theta = 4.113, threshold = 1.677
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config6_mode3_beta2=1.33_thres=1.68.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config6_mode3_beta2=1.33_thres=1.68.pdf
# Config 6, Mode 4: theta = 5.684, threshold = 1.274
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config6_mode4_beta2=1.33_thres=1.27.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config6_mode4_beta2=1.33_thres=1.27.pdf
# Config 6, Mode 5: theta = 6.376, threshold = 1.593
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config6_mode5_beta2=1.33_thres=1.59.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config6_mode5_beta2=1.33_thres=1.59.pdf
# Config 6, Mode 6: theta = 7.061, threshold = 1.063
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config6_mode6_beta2=1.33_thres=1.06.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config6_mode6_beta2=1.33_thres=1.06.pdf
#
# --- Config 7: beta_2 = 1.500 ---
# Config 7, Mode 0: theta = 1.000, threshold = 1.215
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config7_mode0_beta2=1.50_thres=1.22.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config7_mode0_beta2=1.50_thres=1.22.pdf
# Config 7, Mode 1: theta = 1.709, threshold = 1.754
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config7_mode1_beta2=1.50_thres=1.75.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config7_mode1_beta2=1.50_thres=1.75.pdf
# Config 7, Mode 2: theta = 3.057, threshold = 1.718
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config7_mode2_beta2=1.50_thres=1.72.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config7_mode2_beta2=1.50_thres=1.72.pdf
# Config 7, Mode 3: theta = 4.113, threshold = 1.049
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config7_mode3_beta2=1.50_thres=1.05.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config7_mode3_beta2=1.50_thres=1.05.pdf
# Config 7, Mode 4: theta = 5.684, threshold = 1.276
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config7_mode4_beta2=1.50_thres=1.28.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config7_mode4_beta2=1.50_thres=1.28.pdf
# Config 7, Mode 5: theta = 6.376, threshold = 1.914
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config7_mode5_beta2=1.50_thres=1.91.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config7_mode5_beta2=1.50_thres=1.91.pdf
# Config 7, Mode 6: theta = 7.061, threshold = 1.803
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config7_mode6_beta2=1.50_thres=1.80.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config7_mode6_beta2=1.50_thres=1.80.pdf
#
# --- Config 8: beta_2 = 1.667 ---
# Config 8, Mode 0: theta = 1.000, threshold = 1.296
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config8_mode0_beta2=1.67_thres=1.30.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config8_mode0_beta2=1.67_thres=1.30.pdf
# Config 8, Mode 1: theta = 1.709, threshold = 1.064
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config8_mode1_beta2=1.67_thres=1.06.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config8_mode1_beta2=1.67_thres=1.06.pdf
# Config 8, Mode 2: theta = 3.057, threshold = 1.097
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config8_mode2_beta2=1.67_thres=1.10.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config8_mode2_beta2=1.67_thres=1.10.pdf
# Config 8, Mode 3: theta = 4.113, threshold = 1.074
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config8_mode3_beta2=1.67_thres=1.07.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config8_mode3_beta2=1.67_thres=1.07.pdf
# Config 8, Mode 4: theta = 5.684, threshold = 1.966
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config8_mode4_beta2=1.67_thres=1.97.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config8_mode4_beta2=1.67_thres=1.97.pdf
# Config 8, Mode 5: theta = 6.376, threshold = 1.038
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config8_mode5_beta2=1.67_thres=1.04.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config8_mode5_beta2=1.67_thres=1.04.pdf
# Config 8, Mode 6: theta = 7.061, threshold = 1.073
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config8_mode6_beta2=1.67_thres=1.07.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config8_mode6_beta2=1.67_thres=1.07.pdf
#
# --- Config 9: beta_2 = 1.833 ---
# Config 9, Mode 0: theta = 1.000, threshold = 1.660
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config9_mode0_beta2=1.83_thres=1.66.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config9_mode0_beta2=1.83_thres=1.66.pdf
# Config 9, Mode 1: theta = 1.709, threshold = 1.166
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config9_mode1_beta2=1.83_thres=1.17.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config9_mode1_beta2=1.83_thres=1.17.pdf
# Config 9, Mode 2: theta = 3.057, threshold = 1.854
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config9_mode2_beta2=1.83_thres=1.85.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config9_mode2_beta2=1.83_thres=1.85.pdf
# Config 9, Mode 3: theta = 4.113, threshold = 1.756
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config9_mode3_beta2=1.83_thres=1.76.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config9_mode3_beta2=1.83_thres=1.76.pdf
# Config 9, Mode 4: theta = 5.684, threshold = 1.247
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config9_mode4_beta2=1.83_thres=1.25.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config9_mode4_beta2=1.83_thres=1.25.pdf
# Config 9, Mode 5: theta = 6.376, threshold = 1.698
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config9_mode5_beta2=1.83_thres=1.70.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config9_mode5_beta2=1.83_thres=1.70.pdf
# Config 9, Mode 6: theta = 7.061, threshold = 1.303

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from pde import CartesianGrid, ScalarField, PDEBase, MemoryStorage
from scipy.io import savemat

# Fixed parameters
beta_1 = 1
sigma = 0.2
N = 7
# Fixed eigenvalues for each mode
lambda_val = [0, 0.7091, 2.0567, 3.1134, 4.6842, 5.3759, 6.0607]

# Directory for saving data files and figures
save_dir = '/content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/'
os.makedirs(save_dir, exist_ok=True)

# Number of configurations to generate (config numbers 0 to 19)
num_configs = 0
# Generate 20 random beta_2 values uniformly distributed between 0.5 and 2
beta2_values = np.random.uniform(0.5, 2, num_configs)

# Start configuration numbering at 10
config_num_start = 20

for i, beta_2 in enumerate(beta2_values):
    config_num = config_num_start + i
    print(f"\n--- Config {config_num}: beta_2 = {beta_2:.3f} ---")

    # Randomly generate threshold values for each mode in this config
    thresholds = np.random.uniform(1, 2, N)

    # Loop over the modes (each mode uses its corresponding eigenvalue and a random threshold)
    for mode_num in range(N):
        theta = beta_1 + lambda_val[mode_num]
        current_threshold = thresholds[mode_num]
        print(f"Config {config_num}, Mode {mode_num}: theta = {theta:.3f}, threshold = {current_threshold:.3f}")

        # Define the PDE for the current mode with beta_2 from the current configuration
        class FeynmanKacPDE(PDEBase):
            def __init__(self, theta, sigma, bc='dirichlet'):
                self.theta = theta
                self.sigma = sigma
                self.bc = bc

            def evolution_rate(self, state, t=0):
                state_gradient = state.gradient(bc=self.bc)
                state_laplacian = state.laplace(bc=self.bc)
                x, y = state.grid.cell_coords[..., 0], state.grid.cell_coords[..., 1]

                # Advection in x and y and isotropic diffusion
                advection_x = y * state_gradient[0]
                advection_y = - (self.theta * x + beta_2 * y) * state_gradient[1]
                diffusion = (self.sigma**2 / 2) * state_laplacian
                return advection_x + advection_y + diffusion

        # Create the grid with the domain defined by the current threshold
        grid = CartesianGrid([[-current_threshold, current_threshold],
                              [-current_threshold, current_threshold]], [256, 256])
        # Use a constant initial condition over the grid
        ic = ScalarField(grid, 1)

        # Instantiate the PDE and prepare the storage for simulation data
        pde = FeynmanKacPDE(theta, sigma)
        sampling_interval = 0.1
        storage = MemoryStorage()

        # Solve the PDE for t in [0, 10] with a small timestep
        pde.solve(ic, t_range=10, dt=1e-4, tracker=storage.tracker(sampling_interval))

        # Save the simulation data into a MATLAB file.
        data_filename = os.path.join(
            save_dir,
            f"SafeProb_FK_GeneralGraph_solData_config{config_num}_mode{mode_num}_beta2={beta_2:.2f}_thres={current_threshold:.2f}.mat"
        )
        data_variable_name = f"data_config{config_num}_mode{mode_num}"
        savemat(data_filename, {data_variable_name: np.array(storage.data), 'times': storage.times})
        print(f"Saved data: {data_filename}")

        # (Optional) Plot the solution at selected times and save the plot in PDF format.
        times_to_plot = np.linspace(0, 10, 11)
        fields = []
        for t in times_to_plot:
            closest_index = np.argmin(np.abs(storage.times - t))
            field_data = storage.data[closest_index]
            field = ScalarField(grid, field_data)
            fields.append(field)

        fig, axes = plt.subplots(3, 4, figsize=(16, 12))
        for ax, field, t in zip(axes.flat[:11], fields, times_to_plot):
            field.plot(ax=ax, title=f't = {t:.1f}', vmin=0, vmax=1, cmap='PuBu')
        # Remove any extra subplot
        fig.delaxes(axes.flat[-1])
        plt.tight_layout()

        plot_filename = os.path.join(
            save_dir,
            f"SafeProb_FK_GeneralGraph_Plot_config{config_num}_mode{mode_num}_beta2={beta_2:.2f}_thres={current_threshold:.2f}.pdf"
        )
        plt.savefig(plot_filename)
        plt.close(fig)
        print(f"Saved plot: {plot_filename}")
# Out:
# --- Config 10: beta_2 = 0.537 ---
# Config 10, Mode 0: theta = 1.000, threshold = 1.650
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config10_mode0_beta2=0.54_thres=1.65.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config10_mode0_beta2=0.54_thres=1.65.pdf
# Config 10, Mode 1: theta = 1.709, threshold = 1.412
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config10_mode1_beta2=0.54_thres=1.41.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config10_mode1_beta2=0.54_thres=1.41.pdf
# Config 10, Mode 2: theta = 3.057, threshold = 1.753
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config10_mode2_beta2=0.54_thres=1.75.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config10_mode2_beta2=0.54_thres=1.75.pdf
# Config 10, Mode 3: theta = 4.113, threshold = 1.538
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config10_mode3_beta2=0.54_thres=1.54.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config10_mode3_beta2=0.54_thres=1.54.pdf
# Config 10, Mode 4: theta = 5.684, threshold = 1.997
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config10_mode4_beta2=0.54_thres=2.00.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config10_mode4_beta2=0.54_thres=2.00.pdf
# Config 10, Mode 5: theta = 6.376, threshold = 1.150
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config10_mode5_beta2=0.54_thres=1.15.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config10_mode5_beta2=0.54_thres=1.15.pdf
# Config 10, Mode 6: theta = 7.061, threshold = 1.571
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config10_mode6_beta2=0.54_thres=1.57.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config10_mode6_beta2=0.54_thres=1.57.pdf
#
# --- Config 11: beta_2 = 0.924 ---
# Config 11, Mode 0: theta = 1.000, threshold = 1.425
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config11_mode0_beta2=0.92_thres=1.42.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config11_mode0_beta2=0.92_thres=1.42.pdf
# Config 11, Mode 1: theta = 1.709, threshold = 1.360
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config11_mode1_beta2=0.92_thres=1.36.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config11_mode1_beta2=0.92_thres=1.36.pdf
# Config 11, Mode 2: theta = 3.057, threshold = 1.036
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config11_mode2_beta2=0.92_thres=1.04.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config11_mode2_beta2=0.92_thres=1.04.pdf
# Config 11, Mode 3: theta = 4.113, threshold = 1.955
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config11_mode3_beta2=0.92_thres=1.95.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config11_mode3_beta2=0.92_thres=1.95.pdf
# Config 11, Mode 4: theta = 5.684, threshold = 1.454
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config11_mode4_beta2=0.92_thres=1.45.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config11_mode4_beta2=0.92_thres=1.45.pdf
# Config 11, Mode 5: theta = 6.376, threshold = 1.956
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config11_mode5_beta2=0.92_thres=1.96.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config11_mode5_beta2=0.92_thres=1.96.pdf
# Config 11, Mode 6: theta = 7.061, threshold = 1.344
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config11_mode6_beta2=0.92_thres=1.34.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config11_mode6_beta2=0.92_thres=1.34.pdf
#
# --- Config 12: beta_2 = 1.873 ---
# Config 12, Mode 0: theta = 1.000, threshold = 1.622
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config12_mode0_beta2=1.87_thres=1.62.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config12_mode0_beta2=1.87_thres=1.62.pdf
# Config 12, Mode 1: theta = 1.709, threshold = 1.433
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config12_mode1_beta2=1.87_thres=1.43.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config12_mode1_beta2=1.87_thres=1.43.pdf
# Config 12, Mode 2: theta = 3.057, threshold = 1.960
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config12_mode2_beta2=1.87_thres=1.96.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config12_mode2_beta2=1.87_thres=1.96.pdf
# Config 12, Mode 3: theta = 4.113, threshold = 1.988
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config12_mode3_beta2=1.87_thres=1.99.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config12_mode3_beta2=1.87_thres=1.99.pdf
# Config 12, Mode 4: theta = 5.684, threshold = 1.887
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config12_mode4_beta2=1.87_thres=1.89.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config12_mode4_beta2=1.87_thres=1.89.pdf
# Config 12, Mode 5: theta = 6.376, threshold = 1.441
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config12_mode5_beta2=1.87_thres=1.44.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config12_mode5_beta2=1.87_thres=1.44.pdf
# Config 12, Mode 6: theta = 7.061, threshold = 1.851
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config12_mode6_beta2=1.87_thres=1.85.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config12_mode6_beta2=1.87_thres=1.85.pdf
#
# --- Config 13: beta_2 = 1.058 ---
# Config 13, Mode 0: theta = 1.000, threshold = 1.436
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config13_mode0_beta2=1.06_thres=1.44.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config13_mode0_beta2=1.06_thres=1.44.pdf
# Config 13, Mode 1: theta = 1.709, threshold = 1.966
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config13_mode1_beta2=1.06_thres=1.97.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config13_mode1_beta2=1.06_thres=1.97.pdf
# Config 13, Mode 2: theta = 3.057, threshold = 1.898
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config13_mode2_beta2=1.06_thres=1.90.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config13_mode2_beta2=1.06_thres=1.90.pdf
# Config 13, Mode 3: theta = 4.113, threshold = 1.714
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config13_mode3_beta2=1.06_thres=1.71.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config13_mode3_beta2=1.06_thres=1.71.pdf
# Config 13, Mode 4: theta = 5.684, threshold = 1.411
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config13_mode4_beta2=1.06_thres=1.41.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config13_mode4_beta2=1.06_thres=1.41.pdf
# Config 13, Mode 5: theta = 6.376, threshold = 1.583
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config13_mode5_beta2=1.06_thres=1.58.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config13_mode5_beta2=1.06_thres=1.58.pdf
# Config 13, Mode 6: theta = 7.061, threshold = 1.284
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config13_mode6_beta2=1.06_thres=1.28.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config13_mode6_beta2=1.06_thres=1.28.pdf
#
# --- Config 14: beta_2 = 0.521 ---
# Config 14, Mode 0: theta = 1.000, threshold = 1.360
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config14_mode0_beta2=0.52_thres=1.36.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config14_mode0_beta2=0.52_thres=1.36.pdf
# Config 14, Mode 1: theta = 1.709, threshold = 1.778
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config14_mode1_beta2=0.52_thres=1.78.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config14_mode1_beta2=0.52_thres=1.78.pdf
# Config 14, Mode 2: theta = 3.057, threshold = 1.868
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config14_mode2_beta2=0.52_thres=1.87.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config14_mode2_beta2=0.52_thres=1.87.pdf
# Config 14, Mode 3: theta = 4.113, threshold = 1.859
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config14_mode3_beta2=0.52_thres=1.86.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config14_mode3_beta2=0.52_thres=1.86.pdf
# Config 14, Mode 4: theta = 5.684, threshold = 1.853
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config14_mode4_beta2=0.52_thres=1.85.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config14_mode4_beta2=0.52_thres=1.85.pdf
# Config 14, Mode 5: theta = 6.376, threshold = 1.428
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config14_mode5_beta2=0.52_thres=1.43.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config14_mode5_beta2=0.52_thres=1.43.pdf
# Config 14, Mode 6: theta = 7.061, threshold = 1.139
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config14_mode6_beta2=0.52_thres=1.14.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config14_mode6_beta2=0.52_thres=1.14.pdf
#
# --- Config 15: beta_2 = 1.189 ---
# Config 15, Mode 0: theta = 1.000, threshold = 1.955
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config15_mode0_beta2=1.19_thres=1.95.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config15_mode0_beta2=1.19_thres=1.95.pdf
# Config 15, Mode 1: theta = 1.709, threshold = 1.581
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config15_mode1_beta2=1.19_thres=1.58.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config15_mode1_beta2=1.19_thres=1.58.pdf
# Config 15, Mode 2: theta = 3.057, threshold = 1.177
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config15_mode2_beta2=1.19_thres=1.18.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config15_mode2_beta2=1.19_thres=1.18.pdf
# Config 15, Mode 3: theta = 4.113, threshold = 1.912
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config15_mode3_beta2=1.19_thres=1.91.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config15_mode3_beta2=1.19_thres=1.91.pdf
# Config 15, Mode 4: theta = 5.684, threshold = 1.303
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config15_mode4_beta2=1.19_thres=1.30.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config15_mode4_beta2=1.19_thres=1.30.pdf
# Config 15, Mode 5: theta = 6.376, threshold = 1.362
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config15_mode5_beta2=1.19_thres=1.36.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config15_mode5_beta2=1.19_thres=1.36.pdf
# Config 15, Mode 6: theta = 7.061, threshold = 1.765
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config15_mode6_beta2=1.19_thres=1.77.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config15_mode6_beta2=1.19_thres=1.77.pdf
#
# --- Config 16: beta_2 = 1.118 ---
# Config 16, Mode 0: theta = 1.000, threshold = 1.111
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config16_mode0_beta2=1.12_thres=1.11.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config16_mode0_beta2=1.12_thres=1.11.pdf
# Config 16, Mode 1: theta = 1.709, threshold = 1.978
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config16_mode1_beta2=1.12_thres=1.98.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config16_mode1_beta2=1.12_thres=1.98.pdf
# Config 16, Mode 2: theta = 3.057, threshold = 1.564
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config16_mode2_beta2=1.12_thres=1.56.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config16_mode2_beta2=1.12_thres=1.56.pdf
# Config 16, Mode 3: theta = 4.113, threshold = 1.328
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config16_mode3_beta2=1.12_thres=1.33.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config16_mode3_beta2=1.12_thres=1.33.pdf
# Config 16, Mode 4: theta = 5.684, threshold = 1.355
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config16_mode4_beta2=1.12_thres=1.35.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config16_mode4_beta2=1.12_thres=1.35.pdf
# Config 16, Mode 5: theta = 6.376, threshold = 1.936
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config16_mode5_beta2=1.12_thres=1.94.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config16_mode5_beta2=1.12_thres=1.94.pdf
# Config 16, Mode 6: theta = 7.061, threshold = 1.180
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config16_mode6_beta2=1.12_thres=1.18.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config16_mode6_beta2=1.12_thres=1.18.pdf
#
# --- Config 17: beta_2 = 0.522 ---
# Config 17, Mode 0: theta = 1.000, threshold = 1.182
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config17_mode0_beta2=0.52_thres=1.18.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config17_mode0_beta2=0.52_thres=1.18.pdf
# Config 17, Mode 1: theta = 1.709, threshold = 1.476
# Saved data: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_solData_config17_mode1_beta2=0.52_thres=1.48.mat
# Saved plot: /content/drive/MyDrive/Multi Agent PDE/Data_Beta2_Thres/SafeProb_FK_GeneralGraph_Plot_config17_mode1_beta2=0.52_thres=1.48.pdf
# Config 17, Mode 2: theta = 3.057, threshold = 1.135

# %% [markdown]
# Test data generation with timer

# %%
# !pip install py-pde

import os
import time  # Imported for timing
import numpy as np
import matplotlib.pyplot as plt
from pde import CartesianGrid, ScalarField, PDEBase, MemoryStorage
from scipy.io import savemat

# Parameters
beta_1 = 1
beta_2 = 1

N = 7
lambda_val = [0, 0.7091, 2.0567, 3.1134, 4.6842, 5.3759, 6.0607]  # Eigenvalues of the Laplacian matrix of the graph laplacian
threshold = [2, 2, 1.5, 1.5, 1.5, 1.0, 1.0]

# Start overall timer
global_start = time.time()

for mode_num in range(N):
    theta = beta_1 + lambda_val[mode_num]
    sigma = 0.2

    print(f"Processing mode {mode_num} with theta={theta}")

    # Define the PDE
    class FeynmanKacPDE(PDEBase):
        def __init__(self, theta, sigma, bc='dirichlet'):
            self.theta = theta
            self.sigma = sigma
            self.bc = bc

        def evolution_rate(self, state, t=0):
            """ evaluate the right-hand side of the PDE """
            state_gradient = state.gradient(bc=self.bc)
            state_laplacian = state.laplace(bc=self.bc)
            x, y = state.grid.cell_coords[..., 0], state.grid.cell_coords[..., 1]

            # Calculate the components
            advection_x = y * state_gradient[0]
            advection_y = - (self.theta * x + beta_2 * y) * state_gradient[1]
            diffusion = (self.sigma**2 / 2) * state_laplacian

            return advection_x + advection_y + diffusion

    # Create the grid
    grid = CartesianGrid([[-threshold[mode_num], threshold[mode_num]],
                            [-threshold[mode_num], threshold[mode_num]]], [256, 256])

    # Initial conditions
    ic = ScalarField(grid, 1)

    # Instantiate the PDE
    pde = FeynmanKacPDE(theta, sigma)

    # Solve the PDE and store the results
    sampling_interval = 0.1
    storage = MemoryStorage()

    # Start timer for data generation (PDE solving)
    start_time = time.time()
    pde.solve(ic, t_range=10, dt=1e-4, tracker=storage.tracker(sampling_interval))
    elapsed_time = time.time() - start_time
    print(f"Mode {mode_num}: Data generation took {elapsed_time:.2f} seconds.")

    # Save the data for MATLAB analysis with labeled filename and variable name
    data_filename = f'SafeProb_FK_GeneralGraph_solData_(lambda_{mode_num},sigma={sigma}).mat'
    data_variable_name = f'data_lambda_{mode_num}'
    savemat(data_filename, {data_variable_name: np.array(storage.data), 'times': storage.times})

    # Extract the stored data for t = 0, 1, 2, ..., 10
    times_to_plot = np.linspace(0, 10, 11)
    fields = []
    for t in times_to_plot:
        # Find the index of the closest time in storage
        closest_index = np.argmin(np.abs(storage.times - t))
        field_data = storage.data[closest_index]
        field = ScalarField(grid, field_data)
        fields.append(field)

    # Plot the results
    fig, axes = plt.subplots(3, 4, figsize=(16, 12))
    for ax, field, t in zip(axes.flat[:11], fields, times_to_plot):
        field.plot(ax=ax, title=f't={t:.1f}', vmin=0, vmax=1, cmap='PuBu')  # Set colorbar range and colormap

    # Remove the last empty subplot
    fig.delaxes(axes.flat[-1])
    plt.tight_layout()
    plt.show()

    # Create directory for saving figures
    figures_dir = 'Figures_GeneralGraph'
    os.makedirs(figures_dir, exist_ok=True)

    # Save the plots with specified file names
    for t, field in zip(times_to_plot, fields):
        filename = f'{figures_dir}/SafeProb_FK_GeneralGraph_Plot(lambda={lambda_val[mode_num]},sigma={sigma},t={t}).svg'
        fig, ax = plt.subplots()
        field.plot(ax=ax, title=f't={t:.1f}', vmin=0, vmax=1, cmap='PuBu')
        plt.savefig(filename)
        plt.close(fig)

# End overall timer and print total time
global_elapsed = time.time() - global_start
print(f"Total time for data generation across all modes: {global_elapsed:.2f} seconds.")
# Out:
# Requirement already satisfied: py-pde in /usr/local/lib/python3.11/dist-packages (0.44.0)
# Requirement already satisfied: matplotlib>=3.1 in /usr/local/lib/python3.11/dist-packages (from py-pde) (3.10.0)
# Requirement already satisfied: numba>=0.59 in /usr/local/lib/python3.11/dist-packages (from py-pde) (0.60.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from py-pde) (2.0.2)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.11/dist-packages (from py-pde) (1.14.1)
# Requirement already satisfied: sympy>=1.9 in /usr/local/lib/python3.11/dist-packages (from py-pde) (1.13.1)
# Requirement already satisfied: tqdm>=4.66 in /usr/local/lib/python3.11/dist-packages (from py-pde) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1->py-pde) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.59->py-pde) (0.43.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.9->py-pde) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1->py-pde) (1.17.0)
# Processing mode 0 with theta=1
# Mode 0: Data generation took 295.47 seconds.
# Processing mode 1 with theta=1.7090999999999998
# Mode 1: Data generation took 293.53 seconds.
# Processing mode 2 with theta=3.0567
# Mode 2: Data generation took 293.92 seconds.
# Processing mode 3 with theta=4.1134
# Mode 3: Data generation took 291.55 seconds.
# Processing mode 4 with theta=5.6842
# Mode 4: Data generation took 292.85 seconds.
# Processing mode 5 with theta=6.3759
# Mode 5: Data generation took 288.26 seconds.
# Processing mode 6 with theta=7.0607
# Mode 6: Data generation took 291.66 seconds.
# Total time for data generation across all modes: 2079.71 seconds.
